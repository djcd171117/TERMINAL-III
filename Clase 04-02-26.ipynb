# %% [markdown]
# <a href="https://colab.research.google.com/github/djcd171117/TERMINAL-III/blob/main/Clase%2004-02-26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTAR LIBRERIAS

# %%
import math

# %%
math.sqrt(25)

# %%
math.pi

# %%
from match import sqrt, pi

# %%
sqrt(36)

# %%
import math as m

# %%
m.log(10)

# %%
m.e

# %%
m.pow(2,) #x^n = pow (x,n)

# %%
m.factorial(5)

# %%
m.sin(pi/2)

# %%
import random

# %%
random.randint(1,100)

# %%
random.uniform(0,1)

# %%
random.choice(['a', 'B', 'C', 'D'])

# %%
from datetime import datetime, timedelta

# %%
datetime.now()

# %%
hora_actual = datetime.now()

# %%
hora_actual + timedelta(days = 2)

# %%
import os
import sys

# %%
os.getcwd()

# %%
os.name

# %%
sys.version

# %%
import numpy as np

# %%
arr1 = np.array([1, 2, 3, 4, 5])
arr1

# %%
arr2 = np.array([[1, 2, 3]], [4, 5, 6])}
arr2

# %%
arr3= np.array([[1,2], [4, 5, 6]])
arr3

# %%
np.zeros(3)]

# %%
np.zeros((3,3))

# %%
np.ones(4)

# %%
np.ones((4,4))

# %%
np.random.rand(3,3)

# %%
np.linspace(0, 10, 10) #(inicio, fin, cantidad de #)

# %%
arr[-1]

# %%
arr[1:5]

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

a + b ]

# %%
b - a

# %%
a * b

# %%
b / a

# %%
arr1 = np.array([0, np.pi/2, np.pi])

# %%
np.sin(arr1)

# %%
np.cos(arr1)

# %%
np.exp(arr1)

# %%
np.log(arr1)

# %%
np.log(arr1 + 1)

# %%
arr = np.array([10, 20, 30, 40, 50])

# %%
np.mean(arr)

# %%
np.median(arr)

# %%
np.std(arr)

# %%
np.var(arr)

# %%
np.min(arr)

# %%
np.max(arr)

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[3,4],[5,6]])

# %%
A + B

# %%
B - A

# %%
A * B

# %%
np.matmul(A, B)

# %%
A @ B

# %%
np.dot(A, B)

# %%
np.cross(A, B)

# %%
A= np.array([[[1,2,10], [3,4,20]]])
B = np. array([[[5,6,30],[7,8,40]]])
np.cross(A, B)

# %%
from numpu.linalg import det, inv
A
det(A)
inv(A)

# %%
np.matmul(A, inv(A))
A.T

# %%
from numpy.linalg import eig

# %%
M ? np.array([[2,-1], [-1, 2]])
M

# %%
eigenvalores, eigenvectores = eig(M)

# %%
eigenvalores

# %%
eigenvectores

# %% [markdown]
# ### NORMAS

# %%
v = np.array([3,4])

# %%
norm_l2 = np.linalg.norm(v)
norma_l2

# %% [markdown]
# #NORMAL L1 // NORMA MANHATTAN

# %%
n_l1 = np.linalg.norm(v, ord = 1)
n_l1

# %%
np.linalg.norm(v, ord = np.inf)

# %% [markdown]
# # PANDAS

# %%
import pandas as pd

# %%
pd.Series([10,20,30,40,50])

# %%
pd.DataFrame([[10,20,30,40,50])

# %%
data = [1, 2, 3, 4, 5, 6, 7]
pd.DataFrame(data, columns = ['Numeros'],
             index = ['Lun', 'Mar', 'Mie', 'Jue', 'Vie', 'Sab', 'Dom'])

# %%
data = [['Omar', 29], ['Fer', 28], ['Juan', 30]]

df = pd.DataFrame(data, columns = ['Nombre', 'Edad'])

df

# %%
datos = {
    'Nombre' : ['Ana', 'Carlos', 'Luis', 'Maria'], 'Sexo': ['M', 'H', 'H', 'M'], 'Calificaciones': [10, 9, 8, 9.5]}
    pd.DataFrame(datos)

# %%
import yfinance as yf

# %%
df_aapl= yf.download('AAPL', start = "2024-01-01",
                            end = "2026-01-01")
# Out:
# /tmp/ipython-input-567977449.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_aapl= yf.download('AAPL', start = "2024-01-01",
# [*********************100%***********************]  1 of 1 completed

# %%
df_aapl
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-01-02  183.903244  186.677052  182.169616  185.399112  82488700
# 2024-01-03  182.526230  184.140985  181.713894  182.496512  58414500
# 2024-01-04  180.208130  181.377083  179.187767  180.445875  71983600
# 2024-01-05  179.484940  181.050159  178.484394  180.287374  62379700
# 2024-01-08  183.823975  183.863609  179.801961  180.386437  59144500
# ...                ...         ...         ...         ...       ...
# 2025-12-24  273.809998  275.429993  272.200012  272.339996  17910600
# 2025-12-26  273.399994  275.369995  272.859985  274.160004  21521800
# 2025-12-29  273.760010  274.359985  272.350006  272.690002  23715200
# 2025-12-30  273.079987  274.079987  272.279999  272.809998  22139600
# 2025-12-31  271.859985  273.679993  271.750000  273.059998  27293600
#
# [502 rows x 5 columns]

# %%
df_aapl.to_excel("finanzas_apple.xlsx")

# %%
df_aapl.to_csv("finanzas_apple.cvs")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1051723339.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
