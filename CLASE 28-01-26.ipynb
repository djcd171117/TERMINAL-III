# %% [markdown]
# <a href="https://colab.research.google.com/github/djcd171117/TERMINAL-III/blob/main/CLASE%2028-01-26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
  if n == 0 or n == 1: #Caso Base
    return 1
  else:
      return n* factorial(n-1)

# %%
factorial (5)
# Out:
# 120

# %% [markdown]
# #SERIE DE FIBONACCI: 0 1 1 2 3 5 8 ...
