# %% [markdown]
# <a href="https://colab.research.google.com/github/djcd171117/TERMINAL-III/blob/main/090226.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
df_aapl=yf.download('AAPL',start="2024-01-01", end='2026-01-01')
df_aapl
# Out:
# /tmp/ipython-input-2414703401.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_aapl=yf.download('AAPL',start="2024-01-01", end='2026-01-01')
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-01-02  183.903229  186.677036  182.169601  185.399096  82488700
# 2024-01-03  182.526230  184.140985  181.713894  182.496512  58414500
# 2024-01-04  180.208145  181.377098  179.187783  180.445890  71983600
# 2024-01-05  179.484955  181.050175  178.484409  180.287390  62379700
# 2024-01-08  183.823975  183.863609  179.801961  180.386437  59144500
# ...                ...         ...         ...         ...       ...
# 2025-12-24  273.809998  275.429993  272.200012  272.339996  17910600
# 2025-12-26  273.399994  275.369995  272.859985  274.160004  21521800
# ...

# %%
#df_aapl = pd.read_csv("")
df_aapl.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-01-02  183.903229  186.677036  182.169601  185.399096  82488700
# 2024-01-03  182.526230  184.140985  181.713894  182.496512  58414500
# 2024-01-04  180.208145  181.377098  179.187783  180.445890  71983600
# 2024-01-05  179.484955  181.050175  178.484409  180.287390  62379700
# 2024-01-08  183.823975  183.863609  179.801961  180.386437  59144500

# %%
import pandas as pd

# %%
print(df_aapl.head())
# Out:
# Price            Close        High         Low        Open    Volume     Rango
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-01-02  183.903229  186.677036  182.169601  185.399096  82488700  4.507435
# 2024-01-03  182.526230  184.140985  181.713894  182.496512  58414500  2.427091
# 2024-01-04  180.208145  181.377098  179.187783  180.445890  71983600  2.189316
# 2024-01-05  179.484955  181.050175  178.484409  180.287390  62379700  2.565766
# 2024-01-08  183.823975  183.863609  179.801961  180.386437  59144500  4.061648

# %%
df_aapl.reset_index(inplace=True)

# %%
df_aapl.columns = ['Date', Close', 'High', 'Low', 'Open', 'Volume']
df_aapl.head(10)
# Out:
#   File "/tmp/ipython-input-4256181298.py", line 1
#     df_aapl.columns = ['Date', Close', 'High', 'Low', 'Open', 'Volume']
#                                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df_aapl.iloc[2:,:].reset_index(drop = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-881054179.py in <cell line: 0>()
# ----> 1 df_aapl.iloc[2:,:].reset_index(drop = True)
#
# NameError: name 'df_aapl' is not defined

# %%
df_aapl.tail(10) #Puedo ver las ultimas 10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-207239324.py in <cell line: 0>()
# ----> 1 df_aapl.tail(10) #Puedo ver las ultimas 10
#
# NameError: name 'df_aapl' is not defined

# %%
df_aapl.info() #Me dice toda la parte estructural de mi archivo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3181463751.py in <cell line: 0>()
# ----> 1 df_aapl.info() #Me dice toda la parte estructural de mi archivo
#
# NameError: name 'df_aapl' is not defined

# %%
df_aapl['Date'] = pd.to_datetime(df_aapl['Date'])
df_aapl['Close'] = df_aapl.Close.astype('float')
df_aapl['High'] = df_aapl.Close.astype('float')
df_aapl['Close'] = df_aapl.Close.astype('float')
df_aapl['Volume'] = df_aapl.Close.astype('float')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1387421743.py in <cell line: 0>()
# ----> 1 df_aapl['Date'] = pd.to_datetime(df_aapl['Date'])
#       2 df_aapl['Close'] = df_aapl.Close.astype('float')
#       3 df_aapl['High'] = df_aapl.Close.astype('float')
#       4 df_aapl['Close'] = df_aapl.Close.astype('float')
#       5 df_aapl['Volume'] = df_aapl.Close.astype('float')
#
# NameError: name 'pd' is not defined

# %%
df_aapl.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-595295194.py in <cell line: 0>()
# ----> 1 df_aapl.describe()
#
# NameError: name 'df_aapl' is not defined

# %%
df_aapl.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3685953581.py in <cell line: 0>()
# ----> 1 df_aapl.dtypes
#
# NameError: name 'df_aapl' is not defined

# %%
df_aapl[df_aapl.Open > 250] #Para filtrar condiciones son corchetes, nombre de archivo, columna y la condición
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1290021005.py in <cell line: 0>()
# ----> 1 df_aapl[df_aapl.Open > 250] #Para filtrar condiciones son corchetes, nombre de archivo, columna y la condición
#
# NameError: name 'df_aapl' is not defined

# %%
df.aapl[(df_aapl.Open < 250) & (df_aapl.Open > 100)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-967294930.py in <cell line: 0>()
# ----> 1 df.aapl[(df_aapl.Open < 250) & (df_aapl.Open > 100)]
#
# NameError: name 'df' is not defined

# %%
df_aapl.loc[df_aapl.Open > 250, "Status"] = 'Atipico'
df_aapl
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2735485470.py in <cell line: 0>()
# ----> 1 df_aapl.loc[df_aapl.Open > 250, "Status"] = 'Atipico'
#       2 df_aapl
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     905             maybe_callable = com.apply_if_callable(key, self.obj)
#     906             key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 907         indexer = self._get_setitem_indexer(key)
#     908         self._has_valid_setitem_indexer(key)
#     909
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     772             with suppress(IndexingError):
#     773                 # suppress "Too many indexers"
# --> 774                 return self._convert_tuple(key)
#     775
# ...

# %%
df_aapl.loc[df_aapl.Close > df_aapl.Close.shift(1), 'Tendencia'] = 'Sube' #Shift Compara con un valor anterior, el numero indica con que filas comparara
df_aapl.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4266333446.py in <cell line: 0>()
# ----> 1 df_aapl.loc[df_aapl.Close > df_aapl.Close.shift(1), 'Tendencia'] = 'Sube' #Shift Compara con un valor anterior, el numero indica con que filas comparara
#       2 df_aapl.head(10)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     905             maybe_callable = com.apply_if_callable(key, self.obj)
#     906             key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 907         indexer = self._get_setitem_indexer(key)
#     908         self._has_valid_setitem_indexer(key)
#     909
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     772             with suppress(IndexingError):
# ...

# %%
df_aapl.loc[df_aapl.Close < df_aapl.Close.shift(1), 'Tendencia'] = 'Sube' #Shift Compara con un valor anterior, el numero indica con que filas comparara
df_aapl.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3062464207.py in <cell line: 0>()
# ----> 1 df_aapl.loc[df_aapl.Close < df_aapl.Close.shift(1), 'Tendencia'] = 'Sube' #Shift Compara con un valor anterior, el numero indica con que filas comparara
#       2 df_aapl.head(10)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     905             maybe_callable = com.apply_if_callable(key, self.obj)
#     906             key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 907         indexer = self._get_setitem_indexer(key)
#     908         self._has_valid_setitem_indexer(key)
#     909
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     772             with suppress(IndexingError):
# ...

# %%
df_aapl.sort_values(by = 'High', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3196280039.py in <cell line: 0>()
# ----> 1 df_aapl.sort_values(by = 'High', ascending = False)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1923
#    1924             label_axis_name = "column" if axis == 0 else "index"
# -> 1925             raise ValueError(
#    1926                 f"The {label_axis_name} label '{key}' is not unique.{multi_message}"
#    1927             )
#
# ...

# %%
df_aapl.sort_values(by = ['Tendencia', 'High'],
                    ascending = [True, False]) #La primera que ordena es de forma ascendente y la segunda de forma descendente

# %%
df_aapl['Rango'] = df_aapl['High'] - df_aapl['Low']
df_aapl
# Out:
# Price            Close        High         Low        Open    Volume     Rango
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-01-02  183.903229  186.677036  182.169601  185.399096  82488700  4.507435
# 2024-01-03  182.526230  184.140985  181.713894  182.496512  58414500  2.427091
# 2024-01-04  180.208145  181.377098  179.187783  180.445890  71983600  2.189316
# 2024-01-05  179.484955  181.050175  178.484409  180.287390  62379700  2.565766
# 2024-01-08  183.823975  183.863609  179.801961  180.386437  59144500  4.061648
# ...                ...         ...         ...         ...       ...       ...
# 2025-12-24  273.809998  275.429993  272.200012  272.339996  17910600  3.229980
# 2025-12-26  273.399994  275.369995  272.859985  274.160004  21521800  2.510010
# 2025-12-29  273.760010  274.359985  272.350006  272.690002  23715200  2.009979
# 2025-12-30  273.079987  274.079987  272.279999  272.809998  22139600  1.799988
# ...

# %%
df_aapl.Tendencia.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3612827251.py in <cell line: 0>()
# ----> 1 df_aapl.Tendencia.unique()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Tendencia'

# %%
df_aapl.Tendencia.nunqique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2391652828.py in <cell line: 0>()
# ----> 1 df_aapl.Tendencia.nunqique()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Tendencia'

# %%
import datetime as dt

# %%
df_aapl['Year'] = df_aapl.Date.df.year
df_aapl['Month'] = df_aapl.Date.df.Month
df_aapl['day'] = df_aapl.Date.df.day
df_aapl['Week_day'] = df_aapl.Date.df.weekday
df_aapl.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2375519125.py in <cell line: 0>()
# ----> 1 df_aapl['Year'] = df_aapl.Date.df.year
#       2 df_aapl['Month'] = df_aapl.Date.df.Month
#       3 df_aapl['day'] = df_aapl.Date.df.day
#       4 df_aapl['Week_day'] = df_aapl.Date.df.weekday
#       5 df_aapl.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
df_aapl = df_aapl.drop(columns = ['Status', 'Tendencia'])
df_aapl.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2981331043.py in <cell line: 0>()
# ----> 1 df_aapl = df_aapl.drop(columns = ['Status', 'Tendencia'])
# ...

# %%
col = ['Date', 'Year', 'Month', 'Day', 'Week_Day']
df_aapl[[col]].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2204656517.py in <cell line: 0>()
#       1 col = ['Date', 'Year', 'Month', 'Day', 'Week_Day']
# ----> 2 df_aapl[[col]].head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in _get_indexer_strict(self, key, axis_name)
#    2764             return self[indexer], indexer
#    2765
# -> 2766         return super()._get_indexer_strict(key, axis_name)
#    2767
#    2768     def _raise_if_missing(self, key, indexer, axis_name: str) -> None:
#
# ...

# %%
df_aapl[['Close', 'Open', 'High' 'Low']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1840901510.py in <cell line: 0>()
# ----> 1 df_aapl[['Close', 'Open', 'High' 'Low']].head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in _get_indexer_strict(self, key, axis_name)
#    2761             indexer = self._get_indexer_level_0(keyarr)
#    2762
# -> 2763             self._raise_if_missing(key, indexer, axis_name)
#    2764             return self[indexer], indexer
#    2765
#
# ...

# %%
df_msft = yf.download('MSFT', start = '2024-01-01',
                      end = '2026-01-01')
# Out:
# /tmp/ipython-input-4204880019.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_msft = yf.download('MSFT', start = '2024-01-01',
# [*********************100%***********************]  1 of 1 completed

# %%
df_msft = df_msft.reset_index()
df_msft.columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volumen']

# %%
df_msft.head()
# Out:
#         Date       Close        High         Low        Open   Volumen
# 0 2024-01-02  365.421661  370.377766  361.381887  368.367727  25258600
# 1 2024-01-03  365.155579  367.776505  363.096286  363.588941  23083500
# 2 2024-01-04  362.534668  367.618867  361.775991  365.224573  20901500
# 3 2024-01-05  362.347473  366.594154  361.115837  363.549552  21004600
# 4 2024-01-08  369.185455  369.687973  363.588907  363.874625  23134000

# %%
pd.concat([df_aapl,df_msft], ignore_index = True)
# Out:
#        (Date, )  (Close, AAPL)  (High, AAPL)  (Low, AAPL)  (Open, AAPL)  \
# 0    2024-01-02     183.903229    186.677036   182.169601    185.399096
# 1    2024-01-03     182.526230    184.140985   181.713894    182.496512
# 2    2024-01-04     180.208145    181.377098   179.187783    180.445890
# 3    2024-01-05     179.484955    181.050175   178.484409    180.287390
# 4    2024-01-08     183.823975    183.863609   179.801961    180.386437
# ...         ...            ...           ...          ...           ...
# 999         NaT            NaN           NaN          NaN           NaN
# 1000        NaT            NaN           NaN          NaN           NaN
# 1001        NaT            NaN           NaN          NaN           NaN
# 1002        NaT            NaN           NaN          NaN           NaN
# 1003        NaT            NaN           NaN          NaN           NaN
#
#       (Volume, AAPL)  (Rango, )       Date       Close        High  \
# ...

# %%
df_aapl.merge(df_msft, how = ) #El primero se considera a la izquierda, el segundo a la derecha
# how = ['left', 'right', 'outer', 'inner', 'left_outer', 'right_outer']
